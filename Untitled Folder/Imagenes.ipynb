# %%
#Imagenes como arreglos
#svg: trabaja con xml
#Formato de colores: RGBA - RGB
#Se tienen canales multiples y simples
import numpy as np
from scipy import ndimage
from scipy import misc

# %%
mapache = misc.face()
mapache
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
#Dimensiones: 768x1024 en RGB
mapache.shape
# Out:
# (768, 1024, 3)

# %%
type(mapache)
# Out:
# numpy.ndarray

# %%
#Dibujar 
import matplotlib.pyplot as plt

# %%
plt.imshow(mapache)
plt.show()

# %%
imagen_vuelta = mapache[::-1]

# %%
plt.imshow(imagen_vuelta)
plt.show()

# %%
plt.imshow(mapache+200)
plt.show()

# %%
seccion_mapache = mapache[0:100]
plt.imshow(seccion_mapache)
plt.show()

# %%
seccion_mapache = mapache[-100:-1]
#arreglo_dividido = np.vsplit(seccion_mapache, 4)
plt.imshow(seccion_mapache)
plt.show()

# %%
seccion_mapache2 = mapache[-101:-1]
#arreglo_dividido = np.vsplit(seccion_mapache, 4)
seccion_mapache1 = mapache[0:100]
seccion_total = seccion_mapache1 + seccion_mapache2


plt.imshow(seccion_total)
plt.show()

# %%
seccion_mapache2 = mapache[0:50].sum(axis=2)
plt.imshow(seccion_mapache2)
plt.show()
