# %% [markdown]
# # ESCUELA POLITÉCNICA NACIONAL
# # INGENIERÍA EN SISTEMAS INFORMÁTICOS Y DE COMPUTACIÓN
#
# ### Nombre: Chrisitian Benítez
# ### Materia: Python
# ### PROYECTO 1er BIMESTRE

# %% [markdown]
# ## TEMA: ANÁLISIS DE SUICIDIOS ALREDEDOR DEL MUNDO

# %% [markdown]
# **1. INTRODUCCIÓN**

# %% [markdown]
# Los suicidios alrededor del mundo es un tema que se debe de considerar mucho, debido a que existen varios factores por lo cual la gente decide terminar con su propia vida. En los últimos años se han registrado incrementos en la tasa de suicidios de varios paíse del mundo actual.
#
# El siguiente dataset muestra datos de suicidios registrados en distitntos países desde el año de 1987 hasta 2016. Se especificará distintos temas para realziar un análisis completo sobre los suicididos alrededor del mundo.

# %%
import pandas as pd
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt

# %%
path = 'C:/Users/user/Documents/GitHub/py-benitez-chavez-christian-vinicio/Proyecto/DataSet-suicide.xlsx'

# %%
suicide_df = pd.read_excel(path)

# %%
suicide_df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# 5         Albania  1987  female    75+ years            1       35600
# 6         Albania  1987  female  35-54 years            6      278800
# 7         Albania  1987  female  25-34 years            4      257200
# 8         Albania  1987    male  55-74 years            1      137500
# 9         Albania  1987  female   5-14 years            0      311000
# 10        Albania  1987  female  55-74 years            0      144600
# 11        Albania  1987    male   5-14 years            0      338200
# ...

# %% [markdown]
# **2. DESCRIPCIÓN DE COLUMNAS**

# %% [markdown]
# | Atributo           | Descripción                                  |
# | ------------------ | :------------------------------------------: |
# | Country            | País donde ocurrió el suicidio               |
# | Year               | Año en el que ocurrió el suicidio            |
# | Sex                | Género                                       |
# | Age                | Rango de edad que se realiza el suicidio     |
# | N° Suicide         | Cantidad de suicidios por año y país         |
# | Population         | Cantidad de personas                         |
# | Suicides/100k pop  | Tasa de suicidios                            |
# | GDP for year ($)   | PIB por año de cada país                     |
# | Generation         | Generaciones                                 |

# %% [markdown]
# **3. PROBLEMAS PLANTEADOS**

# %% [markdown]
# * **Total de suicidios por país.**

# %%
suicide_df.groupby('country').sum()["suicides_no"].plot(kind='bar',stacked=True, title="Suicidios por países")

# %% [markdown]
# * **Total de suicidios en Ecuador por año.**

# %%
serie_ecuador = suicide_df.iloc[7694:8065]

# %%
suicide_df.groupby('year').count()["suicides_no"].plot(kind='bar',stacked=True,title="Total de suicidios en Ecuador por año")

# %% [markdown]
# * **Cantidad de suicidios totales alrededor de todo el mundo por año.**

# %%
suicidios_totales = suicide_df.groupby('year')['suicides_no'].sum()

# %%
suicidios_totales.plot(kind='line')

# %% [markdown]
# * **Cantidad total de suicidios entre hombres y mujeres**

# %%
anio_sexo = suicide_df.groupby(['year','sex'])
total = anio_sexo['suicides_no'].sum()
suicide_sex = total.unstack()
s_plot = suicide_sex.plot(kind='bar',stacked=True,title="Cantidad total de suicidios entre hombres y mujeres")
s_plot.set_ylabel("Cantidad")
s_plot.set_xlabel("Year")
# Out:
# Text(0.5,0,'Year')

# %% [markdown]
# * **Total de suicidios por generacios por mujeres vs hombres**

# %%
generacion_sexo = serie_ecuador.groupby(['generation','sex'])
total = generacion_sexo['suicides_no'].sum()
suicidio_por_sexo = total.unstack()
s_plot = suicidio_por_sexo.plot(kind='bar',stacked=True,title="Total de suicidios por generacios por mujeres vs hombres")
s_plot.set_ylabel("Cantidad")
s_plot.set_xlabel("Generation")
# Out:
# Text(0.5,0,'Generation')

# %% [markdown]
# * **Población en Ecuador.**

# %%
conteo_generaciones = serie_ecuador.groupby('year')['population'].sum()
conteo_generaciones.plot(kind='line')

# %% [markdown]
# * **Probabilidad de suicidios por población.**

# %%
primeros_Datos = suicide_df.tail(100)
primeros_Datos.plot(kind="line")

# %% [markdown]
# * **Suicidios por año vs edad.**

# %%
estats_peso = serie_ecuador.groupby(['year'])['suicides_no'].describe()
estats_peso.plot(kind='line')

# %% [markdown]
# * **df

# %%
suicide_df.groupby('generation').count()["country"].plot(kind='bar',stacked=True,title="Suicidios por generaciones")

# %%
tabla_general = suicide_df.groupby('age').sum()["suicides_no"]
tabla_general
# Out:
# age
# 15-24 years     808542
# 25-34 years    1123912
# 35-54 years    2452141
# 5-14 years       52264
# 55-74 years    1658443
# 75+ years       653118
# Name: suicides_no, dtype: int64

# %%
plt.pie(tabla_general, labels=["15-24 years", "25-34 years", "35-54 years", "5-14 years", "55-74 years", "75+ years"], autopct="%0.2f %%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1df60f10f60>,
# ...
#  [Text(1.02299,0.404333,'15-24 years'),
#   Text(0.319582,1.05255,'25-34 years'),
#   Text(-1.07789,0.219416,'35-54 years'),
#   Text(-0.626305,-0.904291,'5-14 years'),
#   Text(0.208446,-1.08007,'55-74 years'),
#   Text(1.04955,-0.329321,'75+ years')],
#  [Text(0.557996,0.220545,'11.98 %'),
#   Text(0.174318,0.57412,'16.65 %'),
#   Text(-0.587942,0.119682,'36.34 %'),
#   Text(-0.341621,-0.49325,'0.77 %'),
#   Text(0.113698,-0.589129,'24.58 %'),
#   Text(0.57248,-0.17963,'9.68 %')])
